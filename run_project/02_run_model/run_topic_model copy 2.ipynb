# %%
run_id = input("INPUT 'RUN_ID'(e.g., 1,2,3,4,5): ")
model_in_run = input("INPUT 'model_in_run'(e.g., bert_based, lda, tag): ")
snapshot = input("INPUT 'snapshot'(e.g., public_for_260105): ")
year_range = input("INPUT 'year_range'(e.g., 2021to2023, 2022to2024, 2023to2025, 2021to2024, 2021to2025, 2020to2025): ")
lang=input("INPUT language : ")
# 'typescript'

print(f'{run_id} {model_in_run} {snapshot} {year_range} {lang}')
# Out:
# 1000 bert_based public_for_260105 2020to2025 python

# %%
import lib.topic_modeling.main as tm_main

import run_project.options as op

# %%
runner_opt = op.RunnerOptions(model_in_run, # model_in_run (bert_based or lda)
                              lang, #language#
                              year_range, # year_range (22to24, 21to23)
                              run_id, # run_id 
                              snapshot # snapshot(snapshot1, snapshot2, public_for_260105)
                            )

# %%
runner_opt.user_opt
# Out:
# {'run_id': '1000',
#  'model': 'BERTopic',
#  'year_range': '2020to2025',
#  'data_dir': '/mnt/hdd/mghan/so_data_availability/data/public_for_260105/questions/python/2020to2025',
#  'save_dir': '/mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_1000',
#  'selected_tags': 'python',
#  'snapshot': 'public_for_260105',
#  'model_option': {'model_type': 'text',
#   'clustering': {'name': 'kmeans', 'n_clusters': 20},
#   'nr_topics': None,
#   'vectorizer': 'CountVectorizer',
#   'embedding_model': 'all-MiniLM-L6-v2'},
#  'visualization': {'n': 10}}

# %%
runner = tm_main.ModelRunner(runner_opt)
runner()
# Out:
# {'run_id': '1000',
#  'model': 'BERTopic',
#  'year_range': '2020to2025',
#  'data_dir': '/mnt/hdd/mghan/so_data_availability/data/public_for_260105/questions/python/2020to2025',
#  'save_dir': '/mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_1000',
#  'selected_tags': 'python',
#  'snapshot': 'public_for_260105',
#  'model_option': {'model_type': 'text',
#                   'clustering': {'name': 'kmeans', 'n_clusters': 20},
#                   'nr_topics': None,
#                   'vectorizer': 'CountVectorizer',
#                   'embedding_model': 'all-MiniLM-L6-v2'},
#  'visualization': {'n': 10}}
# [start]   fit and transform together
# 2026-04-08 20:05:10,351 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/21088 [00:00<?, ?it/s]
# 2026-04-08 20:18:24,046 - BERTopic - Embedding - Completed ✓
# 2026-04-08 20:18:24,051 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# ...
