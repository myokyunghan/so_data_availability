# %%
from lib.topic_modeling.main import ModelRunner
from run_project.options import RunnerOptions
from setting_for_sda.constants import CONSTANTS

# %%
for idx, lang in enumerate(CONSTANTS.languages_from2020to2022) :
    print(f"Start bertopic analysis for {lang}")
    runner_opt = RunnerOptions( "bert_based", # model_in_run (bert_based or lda)
                                lang,
                                "2020to2025", # year_range (22to24, 21to23)
                                200+idx, # run_id 
                                "public_for_260105" # snapshot(snapshot1, snapshot2)
                            )
    runner = ModelRunner(runner_opt)
    runner()
    print(f"End bertopic analysis for {lang}")
# Out:
# Start bertopic analysis for python
# {'run_id': 200,
#  'model': 'BERTopic',
#  'year_range': '2020to2025',
#  'data_dir': '/mnt/hdd/mghan/so_data_availability/data/public_for_260105/questions/python/2020to2025',
#  'save_dir': '/mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_200',
#  'selected_tags': 'python',
#  'snapshot': 'public_for_260105',
#  'model_option': {'model_type': 'text',
#                   'clustering': {'name': 'kmeans', 'n_clusters': 50},
#                   'nr_topics': None,
#                   'vectorizer': 'CountVectorizer',
#                   'embedding_model': None},
#  'visualization': {'n': 10}}
# 2026-03-29 20:28:02,436 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/21088 [00:00<?, ?it/s]
# 2026-03-29 20:41:20,888 - BERTopic - Embedding - Completed ✓
# 2026-03-29 20:41:20,892 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# ...
