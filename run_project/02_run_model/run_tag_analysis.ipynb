# %%
from lib.tag_analysis.main import ModelRunner
from run_project.options import RunnerOptions

# %%
runner_opt = RunnerOptions( "tag", # model_in_run (bert_based or lda)
                            "2021to2025", # year_range (22to24, 21to23)
                            6, # run_id 
                            "public_for_260105" # snapshot(snapshot1, snapshot2)
)

# %%
runner_opt.user_opt
# Out:
# {'run_id': 6,
#  'model': 'tag',
#  'year_range': '2021to2025',
#  'data_dir': '/mnt/hdd/mghan/so_data_availability/data/public_for_260105/questions/python/2021to2025',
#  'save_dir': '/mnt/hdd/mghan/so_data_availability/result/tag/run_id_6',
#  'selected_tags': 'python',
#  'snapshot': 'public_for_260105'}

# %%
runner = ModelRunner(runner_opt)
runner()
# Out:
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 97
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_6
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_6/option.json
