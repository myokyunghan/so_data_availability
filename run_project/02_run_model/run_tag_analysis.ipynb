# %%
from lib.tag_analysis.main import ModelRunner
from run_project.options import RunnerOptions
from setting_for_sda.constants import CONSTANTS

# %%
for idx, lang in enumerate(CONSTANTS.languages_from2020to2022) :
    print(f"Start tag analysis for {lang}")
    runner_opt = RunnerOptions( "tag", # model_in_run (bert_based or lda)
                                lang,
                                "2020to2025", # year_range (22to24, 21to23)
                                100+idx, # run_id 
                                "public_for_260105" # snapshot(snapshot1, snapshot2)
                            )
    runner = ModelRunner(runner_opt)
    runner()
    print(f"End tag analysis for {lang}")
# Out:
# Start tag analysis for python
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 153
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_100
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_100/option.json
# End tag analysis for python
# Start tag analysis for javascript
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 108
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_101
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_101/option.json
# End tag analysis for javascript
# Start tag analysis for java
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 57
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_102
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_102/option.json
# End tag analysis for java
# Start tag analysis for c#
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 49
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_103
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_103/option.json
# End tag analysis for c#
# Start tag analysis for c++
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 28
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_104
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_104/option.json
# End tag analysis for c++
# Start tag analysis for c
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 15
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_105
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_105/option.json
# End tag analysis for c
# Start tag analysis for r
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 28
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_106
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_106/option.json
# End tag analysis for r
# Start tag analysis for php
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 28
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_107
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_107/option.json
# End tag analysis for php
# Start tag analysis for swift
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 15
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_108
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_108/option.json
# End tag analysis for swift
# Start tag analysis for kotlin
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 14
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_109
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_109/option.json
# End tag analysis for kotlin
# Start tag analysis for dart
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 13
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_110
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_110/option.json
# End tag analysis for dart
# Start tag analysis for typescript
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 25
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_111
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_111/option.json
# End tag analysis for typescript
# Start tag analysis for go
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 5
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_112
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_112/option.json
# End tag analysis for go
# Start tag analysis for ruby
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 4
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_113
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_113/option.json
# End tag analysis for ruby
# Start tag analysis for rust
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 4
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_114
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_114/option.json
# End tag analysis for rust
# Start tag analysis for scala
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 3
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_115
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_115/option.json
# End tag analysis for scala
# Start tag analysis for julia
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 1
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_116
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_116/option.json
# End tag analysis for julia
# Start tag analysis for matlab
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 2
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_117
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_117/option.json
# End tag analysis for matlab
# Start tag analysis for groovy
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 2
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_118
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_118/option.json
# End tag analysis for groovy
# Start tag analysis for objective-c
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 2
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_119
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_119/option.json
# End tag analysis for objective-c
# Start tag analysis for vb.net
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 2
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_120
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_120/option.json
# End tag analysis for vb.net
# Start tag analysis for assembly
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 3
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_121
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_121/option.json
# End tag analysis for assembly
# Start tag analysis for haskell
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 2
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_122
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_122/option.json
# End tag analysis for haskell
# Start tag analysis for delphi
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 2
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_123
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_123/option.json
# End tag analysis for delphi
# Start tag analysis for lua
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 1
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_124
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_124/option.json
# End tag analysis for lua
# Start tag analysis for perl
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 1
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_125
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_125/option.json
# End tag analysis for perl
# Start tag analysis for prolog
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 1
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_126
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_126/option.json
# End tag analysis for prolog
# Start tag analysis for fortran
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 1
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_127
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_127/option.json
# End tag analysis for fortran
# Start tag analysis for f#
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 1
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_128
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_128/option.json
# End tag analysis for f#
# Start tag analysis for solidity
# DDL executed successfully.
# [Drop view if exists...] SQL_ID : drop_v_tag_proportion Done.
# DDL executed successfully.
# View 'create_v_tag_proportion' created successfully.
# [Create view...] SQL_ID : create_v_tag_proportion Done.
# [Executing query...] SQL_ID : select_v_tag_proportion Done.
# [Saving data...] Chunks: 2
# [Saving data...] Saved to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_129
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_data_availability/result/tag/run_id_129/option.json
# End tag analysis for solidity
