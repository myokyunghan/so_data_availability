# %%
import topic_modeling.main as tm_main
import nltk
from nltk.data import find
import topic_modeling.options as op

def ensure_nltk_resource(resource_path: str, download_name: str):
    try:
        find(resource_path)
    except LookupError:
        nltk.download(download_name)

ensure_nltk_resource("corpora/stopwords", "stopwords")

# %%
# runner_opt = op.RunnerOptions("bert_based", # model_in_run (bert_based or lda)
#                                  "22to24", # year_range (22to24, 21to23)
#                                   5, # run_id 
#                                 "snapshot2" # snapshot(snapshot1, snapshot2)
# )

# %%
# runner = tm_main.ModelRunner(runner_opt)
# runner()

# %%
runner_opt = op.RunnerOptions("lda", # model_in_run (bert_based or lda)
                                 "22to24", # year_range (22to24, 21to23)
                                  7, # run_id 
                                "snapshot2" # snapshot(snapshot1, snapshot2)
)

# %%
runner = tm_main.ModelRunner(runner_opt)
runner()
# Out:
# {'run_id': 7,
#  'model': 'LDA',
#  'year_range': '22to24',
#  'data_dir': '/mnt/hdd/mghan/so_data_availability/data/snapshot2/questions/python/22to24',
#  'save_dir': '/mnt/hdd/mghan/so_data_availability/result/lda',
#  'selected_tags': None,
#  'snapshot': {'snapshot2'},
#  'model_option': {'n_components': 50,
#                   'max_df': 0.8,
#                   'min_df': 10,
#                   'attach_suffix': False},
#  'visualization': {'html': True, 'n': 10}}
# [LDATopicModel] lemmatizing
# [LDA Preprocessing]: 100%|██████████| 182247/182247 [5:10:46<00:00,  9.77it/s]
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  4.1min finished
# iteration: 1 of max_iter: 10
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  3.3min finished
# iteration: 2 of max_iter: 10
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.7min finished
# iteration: 3 of max_iter: 10
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.4min finished
# iteration: 4 of max_iter: 10
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.2min finished
# iteration: 5 of max_iter: 10
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.0min finished
# iteration: 6 of max_iter: 10
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.0min finished
# iteration: 7 of max_iter: 10
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.9min finished
# iteration: 8 of max_iter: 10
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.9min finished
# iteration: 9 of max_iter: 10
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.9min finished
# iteration: 10 of max_iter: 10
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.6min finished
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.6min finished
# [Saving] /mnt/hdd/mghan/so_data_availability/result/lda/run_id_7/topic_info.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/lda/run_id_7/data/0.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/lda/run_id_7/data/1.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/lda/run_id_7/data/2.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/lda/run_id_7/data/3.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/lda/run_id_7/data/4.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/lda/run_id_7/data/5.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/lda/run_id_7/data/6.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/lda/run_id_7/data/7.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/lda/run_id_7/data/8.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/lda/run_id_7/data/9.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/lda/run_id_7/data/10.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/lda/run_id_7/data/11.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/lda/run_id_7/data/12.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/lda/run_id_7/data/13.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/lda/run_id_7/data/14.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/lda/run_id_7/data/15.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/lda/run_id_7/data/16.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/lda/run_id_7/data/17.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/lda/run_id_7/data/18.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/lda/run_id_7/option.json
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 runner = tm_main.ModelRunner(runner_opt)
# ----> 2 runner()
#
# File ~/sopjt/git/so_data_availability/topic_modeling/main.py:31, in ModelRunner.__call__(self)
#      30 def __call__(self):
# ---> 31     self.run()
#
# File ~/sopjt/git/so_data_availability/topic_modeling/main.py:36, in ModelRunner.run(self)
#      34 pprint.pp(self.option)
#      35 self.run_model_and_save_data()
# ---> 36 self.save_option()
#
# File ~/sopjt/git/so_data_availability/topic_modeling/main.py:143, in ModelRunner.save_option(self)
#     137 def save_option(self):
#     138     """
#     139
#     140     Returns:
#     141         None
#     142     """
# --> 143     save_json(self.option, f'{self.save_dir}/option.json')
#
# File ~/sopjt/git/so_data_availability/utils/file_io.py:32, in save_json(to_save, path)
#      30 print(f"[Saving] {path}")
#      31 with open(path, 'w') as file:
# ---> 32     json.dump(to_save, file, ensure_ascii=False, indent=4)
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/json/__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# --> 179 for chunk in iterable:
#     180     fp.write(chunk)
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/json/encoder.py:431, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     429     yield from _iterencode_list(o, _current_indent_level)
#     430 elif isinstance(o, dict):
# --> 431     yield from _iterencode_dict(o, _current_indent_level)
#     432 else:
#     433     if markers is not None:
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/json/encoder.py:405, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     403         else:
#     404             chunks = _iterencode(value, _current_indent_level)
# --> 405         yield from chunks
#     406 if newline_indent is not None:
#     407     _current_indent_level -= 1
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/json/encoder.py:438, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     436         raise ValueError("Circular reference detected")
#     437     markers[markerid] = o
# --> 438 o = _default(o)
#     439 yield from _iterencode(o, _current_indent_level)
#     440 if markers is not None:
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/json/encoder.py:179, in JSONEncoder.default(self, o)
#     160 def default(self, o):
#     161     """Implement this method in a subclass such that it returns
#     162     a serializable object for ``o``, or calls the base implementation
#     163     (to raise a ``TypeError``).
#    (...)
#     177
#     178     """
# --> 179     raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                     f'is not JSON serializable')
#
# TypeError: Object of type set is not JSON serializable
