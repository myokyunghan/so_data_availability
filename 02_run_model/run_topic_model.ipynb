# %%
import topic_modeling.main as tm_main
import nltk
from nltk.data import find

def ensure_nltk_resource(resource_path: str, download_name: str):
    try:
        find(resource_path)
    except LookupError:
        nltk.download(download_name)

# 사용 예
ensure_nltk_resource("corpora/stopwords", "stopwords")

# %%
runner = tm_main.ModelRunner()
runner()
# Out:
# {'run_id': 5,
#  'year_range': '22to24',
#  'data_dir': '/mnt/hdd/mghan/so_data_availability/data/snapshot2/questions/python/22to24',
#  'save_dir': '/mnt/hdd/mghan/so_data_availability/result/bert_based',
#  'selected_tags': None,
#  'snapshot': '2',
#  'model_option': {'model_type': 'text',
#                   'clustering': {'name': 'kmeans', 'n_clusters': 50},
#                   'nr_topics': None,
#                   'vectorizer': 'CountVectorizer',
#                   'embedding_model': None},
#  'visualization': {'n': 10}}
# 2026-01-18 21:03:53,570 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/5696 [00:00<?, ?it/s]
# 2026-01-18 21:07:32,037 - BERTopic - Embedding - Completed ✓
# 2026-01-18 21:07:32,040 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# /home/mghan/sopjt/git/so_data_availability/venv_so_data_availability/lib/python3.10/site-packages/numba/np/ufunc/parallel.py:373: NumbaWarning:
#
# The TBB threading layer requires TBB version 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#
# 2026-01-18 21:09:04,968 - BERTopic - Dimensionality - Completed ✓
# 2026-01-18 21:09:04,974 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2026-01-18 21:09:05,803 - BERTopic - Cluster - Completed ✓
# 2026-01-18 21:09:05,835 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2026-01-18 21:09:44,374 - BERTopic - Representation - Completed ✓
# [Saving] /mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_5/topic_info.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_5/data/0.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_5/data/1.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_5/data/2.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_5/data/3.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_5/data/4.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_5/data/5.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_5/data/6.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_5/data/7.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_5/data/8.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_5/data/9.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_5/data/10.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_5/data/11.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_5/data/12.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_5/data/13.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_5/data/14.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_5/data/15.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_5/data/16.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_5/data/17.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_5/data/18.json
# [Saving] /mnt/hdd/mghan/so_data_availability/result/bert_based/run_id_5/option.json
